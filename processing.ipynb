# %% [markdown]
# # Библиотеки

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import numpy as np

# %%
formatted_rlst.drop(['Название ЖК','Серия дома'],axis=1,inplace=True)
formatted_rlst.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19737 entries, 0 to 19736
# Data columns (total 23 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   index                     int64
#  1   ID  объявления            int64
#  2   Количество комнат         object
#  3   Тип                       object
#  4   Метро                     object
#  5   Адрес                     object
#  6   Площадь, м2               object
#  7   Дом                       object
#  8   Парковка                  object
#  9   Цена                      object
#  10  Телефоны                  object
#  11  Описание                  object
#  12  Ремонт                    object
#  13  Площадь комнат, м2        object
#  14  Балкон                    object
#  15  Окна                      object
#  16  Санузел                   object
#  17  Можно с детьми/животными  object
#  18  Дополнительно             object
#  19  Высота потолков, м        float64
# ...

# %% [markdown]
# ### Ещё отбросим
# Также отбросим столбцы, которые никак не могут повлиять на цену

# %%
#formatted_rlst= formatted_rlst.convert_dtypes()

formatted_rlst.drop(columns=['Телефоны','Ссылка на объявление'],inplace=True)
formatted_rlst.info()
formatted_rlst.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19737 entries, 0 to 19736
# Data columns (total 22 columns):
#  #   Column                    Dtype
# ---  ------                    -----
#  0   index                     int64
#  1   ID  объявления            int64
#  2   Количество комнат         object
#  3   Тип                       object
#  4   Метро                     object
#  5   Адрес                     object
#  6   Площадь, м2               object
#  7   Дом                       object
#  8   Парковка                  object
#  9   Цена                      object
#  10  Описание                  object
#  11  Ремонт                    object
#  12  Площадь комнат, м2        object
#  13  Балкон                    object
#  14  Окна                      object
#  15  Санузел                   object
#  16  Можно с детьми/животными  object
#  17  Дополнительно             object
#  18  Высота потолков, м        float64
#  19  Лифт                      object
# ...

# %% [markdown]
# ## ~~Корреляция~~
# Work in progress...

# %%
categories = ['Парковка', 'Ремонт',
       'Балкон', 'Окна', 'Санузел', 'Можно с детьми/животными',
       'Высота потолков, м', 'Лифт', 'Мусоропровод']
Uniqs
for parametr in formatted_rlst.columns:
    if parametr in categories:
       formatted_rlst[parametr]= formatted_rlst[parametr].astype('category')
#formatted_rlst.info()
coord_rlst= formatted_rlst.select_dtypes(exclude='object')#.corr()
coord_rlst = coord_rlst.apply(lambda x: pd.factorize(x)[0]).corr().round(2)
fig = plt.figure(figsize=(14,8))
sns.heatmap(coord_rlst,annot=True,cmap='RdBu')
# ax,fig= plt.subplots(4,5)
# fig.size()
# for i,label in enumerate( formatted_rlst.columns):
#     ax[i]=sns.countplot(x=rlst[label])
# Out:
# <Axes: >
